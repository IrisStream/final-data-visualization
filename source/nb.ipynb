# %%
import numpy as np  
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sb

# %%
vnm = pd.read_csv('../data/vinamilk.csv')
hnm = pd.read_csv('../data/hanoimilk.csv')

# %%
vnm.head(5)
# Out:
#   Thời gian  Doanh Thu Bán hàng  Marketing  Chi Phí Bán Hàng  \
# 0    Q1-2007               1380000     193200            210000
# 1    Q2-2007               1734000     242760            231000
# 2    Q3-2007               1837000     257180            270000
# 3    Q4-2007               1870000     261800            263000
# 4    Q1-2008               1808000     253120            204000
#
#    Lợi Nhuận Thuần  Giá Bán Trung Bình  Giá Vốn Bán Hàng
# 0              273000                   9968              989000
# 1              221000                   9968             1251000
# 2              173000                   9968             1345000
# 3              193000                   9968             1369000
# 4              334000                   9968             1254000

# %%
hnm.head(5)
# Out:
#   Thời gian  Doanh Thu Bán hàng  Marketing  Chi Phí Bán Hàng  \
# 0    Q1-2007                 40907       3273              9488
# 1    Q2-2007                 83186       6655             17361
# 2    Q3-2007                104760       8381             13288
# 3    Q4-2007                 94975       7598             10316
# 4    Q1-2008                 64914       5193             10588
#
#    Lợi Nhuận Thuần  Giá Bán Trung Bình  Giá Vốn Bán Hàng
# 0                 203                   4800               28084
# 1                6938                   4800               54195
# 2                2019                   4800               84883
# 3                3046                   4800               78116
# 4                -858                   4800               52870

# %%
dataplot = sb.heatmap(hnm.corr(), cmap="YlGnBu", annot=True)
plt.show()

# %%
dataplot = sb.heatmap(vnm.corr(), cmap="YlGnBu", annot=True)
plt.show()
